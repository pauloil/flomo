# %%
# %load_ext autoreload
# %autoreload 2
from __init__ import Flomo, Parser
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
authorization = "Bearer 3669408|Ba29o6NHT4kL8hVUINBofrJaFarE6dWS1qEdjbHt"
flomo = Flomo(authorization)
r = flomo.request()

# %%
import pandas as pd

# %%
df = pd.DataFrame(r)

# %%
tags_ignore = ["故事", "播客"]
df.tags.apply(lambda x: "#" + ";#".join(x))
# Out:
# 0      #画画;#金融
# 1          #画画
# 2         #朋友圈
# 3          #工具
# 4         #朋友圈
#         ...
# 195     #随感/佚名
# 196          #
# 197          #
# 198          #
# 199          #
# Name: tags, Length: 200, dtype: object
